# %% [markdown]
# # Student Marks

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from scipy.stats import zscore

# %%
ds=pd.read_csv(r"C:\Users\shobhit.saxena\Music\Python_New\student_marks.csv")

# %%
ds.head()
# Out:
#   Unnamed: 0 Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0       John      M  05-04-1988     55       45         56       87       21
# 1     Suresh      M  04-05-1987     75       96         78       64       90
# 2     Ramesh      M  25-05-1989     25       54         89       76       95
# 3    Jessica      F  12-08-1990     78       96         86       63       54
# 4   Jennifer      F  02-09-1989     58       96         78       46       96
#
#    Economics  History  Civics
# 0         52       89      65
# 1         61       58       2
# 2         87       56      74
# 3         89       75      45
# 4         77       83      53

# %%
ds.dtypes
# Out:
# Unnamed: 0    object
# Gender        object
# DOB           object
# Maths          int64
# Physics        int64
# Chemistry      int64
# English        int64
# Biology        int64
# Economics      int64
# History        int64
# Civics         int64
# dtype: object

# %%
ds.shape
# Out:
# (10, 11)

# %%
ds.isnull().sum()
# Out:
# Unnamed: 0    0
# Gender        0
# DOB           0
# Maths         0
# Physics       0
# Chemistry     0
# English       0
# Biology       0
# Economics     0
# History       0
# Civics        0
# dtype: int64

# %%
ds['Total Marks']=ds.sum(axis=1)

# %%
ds['Total Marks']
# Out:
# 0    470
# 1    524
# 2    556
# 3    586
# 4    587
# 5    556
# 6    496
# 7    517
# 8    587
# 9    566
# Name: Total Marks, dtype: int64

# %%
ds.rename(columns={"Unnamed: 0":"Name"},inplace=True)

# %%
ds.head()
# Out:
#        Name Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0      John      M  05-04-1988     55       45         56       87       21
# 1    Suresh      M  04-05-1987     75       96         78       64       90
# 2    Ramesh      M  25-05-1989     25       54         89       76       95
# 3   Jessica      F  12-08-1990     78       96         86       63       54
# 4  Jennifer      F  02-09-1989     58       96         78       46       96
#
#    Economics  History  Civics  Total Marks
# 0         52       89      65          470
# 1         61       58       2          524
# 2         87       56      74          556
# 3         89       75      45          586
# 4         77       83      53          587

# %%
plt.bar(ds['Name'],ds['Total Marks'])
plt.figure(figsize=(20, 3))

# %%
ds.groupby("Name")["Total Marks"].sum().sort_values(ascending=False)
# Out:
# Name
# Jennifer    587
# Farha       587
# Jessica     586
# Mukesh      566
# Ramesh      556
# Annu        556
# Suresh      524
# Ritesh      517
# pooja       496
# John        470
# Name: Total Marks, dtype: int64

# %%
plt.scatter(ds['Maths'],ds['Physics'])

# %%
sns.pairplot(ds)

# %%
ds.describe()
# Out:
#            Maths    Physics  Chemistry    English    Biology  Economics  \
# count  10.000000  10.000000  10.000000  10.000000  10.000000  10.000000
# mean   59.600000  72.300000  75.300000  69.700000  64.700000  72.700000
# std    19.460501  20.661559  14.000397  14.453373  26.998148  14.629119
# min    25.000000  45.000000  52.000000  46.000000  21.000000  52.000000
# 25%    54.250000  56.250000  65.000000  59.250000  54.250000  58.750000
# 50%    55.000000  70.000000  78.000000  69.500000  66.500000  76.000000
# 75%    70.750000  93.750000  86.750000  81.250000  87.000000  86.000000
# max    96.000000  96.000000  89.000000  89.000000  96.000000  89.000000
#
#          History   Civics  Total Marks
# count  10.000000  10.0000     10.00000
# mean   69.700000  60.5000    544.50000
# std    14.453373  25.3432     41.01558
# min    46.000000   2.0000    470.00000
# 25%    59.250000  52.2500    518.75000
# 50%    69.500000  63.0000    556.00000
# 75%    81.250000  76.2500    581.00000
# ...

# %%
plt.boxplot(ds['English'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x160b8b38>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x160b8978>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x160b87f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x160e97f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x160e9b38>],
#  'means': []}

# %%
plt.boxplot(ds['Maths'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x16b3bc88>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x16b45358>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x16b3b860>],
#  'medians': [<matplotlib.lines.Line2D at 0x16b459e8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x16b45d30>],
#  'means': []}

# %%
sns.distplot(ds['Maths'])

# %%
plt.boxplot(ds['Maths'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x15e522e8>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x15de6b00>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x15e5a2b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x15f210f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x15f21940>],
#  'means': []}

# %%
dfcor=ds.corr()

# %%
sns.heatmap(dfcor,annot=True)

# %%
numeric_cols = ds.select_dtypes(include=[np.number]).columns
z1=np.abs(zscore(ds[numeric_cols]))
z1
# Out:
# array([[0.24916243, 1.39276651, 1.45310069, 1.26169862, 1.70618534,
#         1.49152635, 1.40755973, 0.18716723, 1.91463575],
#        [0.83415247, 1.20910499, 0.20328352, 0.41570417, 0.98779152,
#         0.84303663, 0.85328751, 2.43317398, 0.52684608],
#        [1.87413478, 0.93361271, 1.03147562, 0.4594625 , 1.18300723,
#         1.03037811, 0.99914862, 0.56150169, 0.2955478 ],
#        [0.99664971, 1.20910499, 0.80560505, 0.48863473, 0.41776163,
#         1.17448693, 0.38653195, 0.64468712, 1.06654206],
#        [0.08666519, 1.20910499, 0.20328352, 1.72845418, 1.22205037,
#         0.30983398, 0.9699764 , 0.31194538, 1.09224187],
#        [0.79081988, 0.7499512 , 1.75426145, 1.40755973, 0.37871849,
#         1.17448693, 1.26169862, 0.3535381 , 0.2955478 ],
#        [0.24916243, 0.42344183, 1.07664973, 0.85328751, 0.40214437,
#         1.05919987, 0.41570417, 0.02079636, 1.24644072],
#        [0.30332817, 0.18876323, 0.88089524, 0.99914862, 1.55001277,
# ...

# %%
threshold=3
print(np.where(z1>3))
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
plt.bar(ds['Gender'],ds['Total Marks'])
# Out:
# <BarContainer object of 10 artists>

# %%
plt.bar(ds['Gender'],ds['Maths'])
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# # Titanic Dataset

# %%
ds1=pd.read_csv(r"C:\Users\shobhit.saxena\Music\Python_New\titanic_train.csv")

# %%
ds1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
ds1.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
ds1.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
ds1['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
ds1['Age'].min()
# Out:
# 0.42

# %%
ds1['Age'].max()
# Out:
# 80.0

# %%
ds1.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
ds1.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
plt.scatter(ds1['Age'],ds1['Fare'])

# %%
ds1['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
ds1=ds1.dropna(subset=['Age'])

# %%
ds1.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          529
# Embarked         2
# dtype: int64

# %%
ds1.shape
# Out:
# (714, 12)

# %%
ds1['Pclass'].value_counts()
# Out:
# 3    355
# 1    186
# 2    173
# Name: Pclass, dtype: int64

# %%
ds1['Embarked'].value_counts()
# Out:
# S    554
# C    130
# Q     28
# Name: Embarked, dtype: int64

# %%
sns.distplot(ds1['Age'])

# %%
ds1['Cabin'].value_counts()
# Out:
# B96 B98            4
# G6                 4
# C23 C25 C27        4
# C22 C26            3
# F2                 3
# D                  3
# F33                3
# F4                 2
# B57 B59 B63 B66    2
# C93                2
# E25                2
# C83                2
# C78                2
# B28                2
# E101               2
# B18                2
# D33                2
# E121               2
# C123               2
# B77                2
# C65                2
# D26                2
# B35                2
# E24                2
# B51 B53 B55        2
# D35                2
# E67                2
# B49                2
# C2                 2
# E8                 2
#                   ..
# D7                 1
# D30                1
# C104               1
# B4                 1
# B69                1
# C49                1
# D47                1
# E38                1
# T                  1
# A5                 1
# E68                1
# C30                1
# ...

# %%
ds1=ds1.dropna(subset=['Cabin'])

# %%
ds1
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# 21            22         1       2
# 23            24         1       1
# 27            28         0       1
# 52            53         1       1
# 54            55         0       1
# 61            62         1       1
# 62            63         0       1
# 66            67         1       2
# 75            76         0       3
# 88            89         1       1
# 92            93         0       1
# 96            97         0       1
# 97            98         1       1
# 102          103         0       1
# 110          111         0       1
# 118          119         0       1
# 123          124         1       2
# 124          125         0       1
# 136          137         1       1
# 137          138         0       1
# ...

# %%
ds1.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       2
# dtype: int64

# %%
from sklearn.impute import SimpleImputer
imp=SimpleImputer(strategy="most_frequent")
ds1["Embarked"]=imp.fit_transform(ds1["Embarked"].values.reshape(-1,1))
ds1
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# 21            22         1       2
# 23            24         1       1
# 27            28         0       1
# 52            53         1       1
# 54            55         0       1
# 61            62         1       1
# 62            63         0       1
# 66            67         1       2
# 75            76         0       3
# 88            89         1       1
# 92            93         0       1
# 96            97         0       1
# 97            98         1       1
# 102          103         0       1
# 110          111         0       1
# 118          119         0       1
# 123          124         1       2
# 124          125         0       1
# 136          137         1       1
# 137          138         0       1
# ...
