# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
ds=pd.read_csv(r"C:\Users\shobhit.saxena\Music\Python_New\Projects\abalone.csv")

# %%
ds
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# 5      I   0.425     0.300   0.095        0.3515          0.1410
# 6      F   0.530     0.415   0.150        0.7775          0.2370
# 7      F   0.545     0.425   0.125        0.7680          0.2940
# 8      M   0.475     0.370   0.125        0.5095          0.2165
# 9      F   0.550     0.440   0.150        0.8945          0.3145
# 10     F   0.525     0.380   0.140        0.6065          0.1940
# 11     M   0.430     0.350   0.110        0.4060          0.1675
# 12     M   0.490     0.380   0.135        0.5415          0.2175
# ...

# %%
ds['Sex'].unique()
# Out:
# array(['M', 'F', 'I'], dtype=object)

# %%
ds.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
ds.dtypes
# Out:
# Sex                object
# Length            float64
# Diameter          float64
# Height            float64
# Whole weight      float64
# Shucked weight    float64
# Viscera weight    float64
# Shell weight      float64
# Rings               int64
# dtype: object

# %%
from sklearn import preprocessing
le=preprocessing.LabelEncoder()
ds['Sex']=le.fit_transform(ds['Sex'])

# %%
ds['Sex']
# Out:
# 0       2
# 1       2
# 2       0
# 3       2
# 4       1
# 5       1
# 6       0
# 7       0
# 8       2
# 9       0
# 10      0
# 11      2
# 12      2
# 13      0
# 14      0
# 15      2
# 16      1
# 17      0
# 18      2
# 19      2
# 20      2
# 21      1
# 22      0
# 23      0
# 24      0
# 25      0
# 26      0
# 27      2
# 28      2
# 29      2
#        ..
# 4147    2
# 4148    2
# 4149    1
# 4150    1
# 4151    1
# 4152    1
# 4153    1
# 4154    1
# 4155    1
# 4156    2
# 4157    2
# 4158    1
# 4159    0
# 4160    0
# 4161    0
# 4162    2
# 4163    1
# 4164    1
# 4165    1
# 4166    1
# 4167    2
# 4168    0
# 4169    2
# 4170    2
# 4171    2
# 4172    0
# 4173    2
# 4174    2
# 4175    0
# 4176    2
# Name: Sex, Length: 4177, dtype: int32

# %%
ds.dtypes
# Out:
# Sex                 int32
# Length            float64
# Diameter          float64
# Height            float64
# Whole weight      float64
# Shucked weight    float64
# Viscera weight    float64
# Shell weight      float64
# Rings               int64
# dtype: object

# %%
ds.shape
# Out:
# (4177, 9)

# %%
ds.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %%
ds.describe()
# Out:
#                Sex       Length     Diameter       Height  Whole weight  \
# count  4177.000000  4177.000000  4177.000000  4177.000000   4177.000000
# mean      1.052909     0.523992     0.407881     0.139516      0.828742
# std       0.822240     0.120093     0.099240     0.041827      0.490389
# min       0.000000     0.075000     0.055000     0.000000      0.002000
# 25%       0.000000     0.450000     0.350000     0.115000      0.441500
# 50%       1.000000     0.545000     0.425000     0.140000      0.799500
# 75%       2.000000     0.615000     0.480000     0.165000      1.153000
# max       2.000000     0.815000     0.650000     1.130000      2.825500
#
#        Shucked weight  Viscera weight  Shell weight        Rings
# count     4177.000000     4177.000000   4177.000000  4177.000000
# mean         0.359367        0.180594      0.238831     9.933684
# std          0.221963        0.109614      0.139203     3.224169
# ...

# %%
plt.boxplot(ds['Length'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x57154e0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x5715b70>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x57150b8>],
#  'medians': [<matplotlib.lines.Line2D at 0x5715f98>],
#  'fliers': [<matplotlib.lines.Line2D at 0x571d588>],
#  'means': []}

# %%
plt.boxplot(ds['Diameter'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x6c62390>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x6c62a20>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x6c59f28>],
#  'medians': [<matplotlib.lines.Line2D at 0x6c62e48>],
#  'fliers': [<matplotlib.lines.Line2D at 0x6c6d438>],
#  'means': []}

# %%
ds.plot(kind="box",subplots=True,layout=(2,7))
# Out:
# Sex                  AxesSubplot(0.125,0.536818;0.0945122x0.343182)
# Length            AxesSubplot(0.238415,0.536818;0.0945122x0.343182)
# Diameter          AxesSubplot(0.351829,0.536818;0.0945122x0.343182)
# Height            AxesSubplot(0.465244,0.536818;0.0945122x0.343182)
# Whole weight      AxesSubplot(0.578659,0.536818;0.0945122x0.343182)
# Shucked weight    AxesSubplot(0.692073,0.536818;0.0945122x0.343182)
# Viscera weight    AxesSubplot(0.805488,0.536818;0.0945122x0.343182)
# Shell weight            AxesSubplot(0.125,0.125;0.0945122x0.343182)
# Rings                AxesSubplot(0.238415,0.125;0.0945122x0.343182)
# dtype: object

# %%
from scipy.stats import zscore
z=np.abs(zscore(ds))
z
# Out:
# array([[1.15198011, 0.57455813, 0.43214879, ..., 0.72621157, 0.63821689,
#         1.57154357],
#        [1.15198011, 1.44898585, 1.439929  , ..., 1.20522124, 1.21298732,
#         0.91001299],
#        [1.28068972, 0.05003309, 0.12213032, ..., 0.35668983, 0.20713907,
#         0.28962385],
#        ...,
#        [1.15198011, 0.6329849 , 0.67640943, ..., 0.97541324, 0.49695471,
#         0.28962385],
#        [1.28068972, 0.84118198, 0.77718745, ..., 0.73362741, 0.41073914,
#         0.02057072],
#        [1.15198011, 1.54905203, 1.48263359, ..., 1.78744868, 1.84048058,
#         0.64095986]])

# %%
treshold=3
print(np.where(z>3))
# Out:
# (array([   6,   72,   81,   83,  129,  163,  164,  165,  165,  165,  166,
#         166,  167,  168,  170,  181,  232,  236,  236,  236,  237,  237,
#         238,  238,  239,  270,  275,  277,  278,  294,  310,  313,  314,
#         334,  351,  355,  358,  358,  362,  375,  416,  417,  428,  431,
#         433,  469,  478,  480,  501,  526,  526,  530,  572,  628,  673,
#         674,  675,  678,  694,  696,  696,  719,  719,  720,  720,  744,
#         754,  756,  811,  891,  891,  891, 1048, 1051, 1051, 1052, 1193,
#        1197, 1199, 1202, 1204, 1206, 1206, 1207, 1207, 1207, 1207, 1209,
#        1209, 1257, 1417, 1417, 1418, 1422, 1426, 1427, 1427, 1427, 1428,
#        1429, 1429, 1528, 1754, 1756, 1757, 1759, 1761, 1762, 1762, 1762,
#        1763, 1763, 1763, 1821, 1982, 1986, 1987, 1987, 2051, 2090, 2108,
#        2108, 2114, 2114, 2157, 2161, 2176, 2180, 2199, 2201, 2208, 2209,
#        2274, 2275, 2305, 2334, 2334, 2334, 2335, 2344, 2358, 2368, 2381,
# ...

# %%
z[6][8]
# Out:
# 3.12251641377204

# %%
z[72][8]
# Out:
# 3.12251641377204

# %%
z[83][8]
# Out:
# 3.4327109831902103

# %%
z[3996][3]
# Out:
# 3.335953189095966

# %%
plt.scatter(ds['Length'],ds['Diameter'])
plt.xlabel("Length")
plt.ylabel("Diameter")
# Out:
# Text(0, 0.5, 'Diameter')

# %%
plt.scatter(ds['Length'],ds['Height'])
plt.xlabel("Length")
plt.ylabel("Diameter")
# Out:
# Text(0, 0.5, 'Diameter')

# %%
sns.pairplot(ds)

# %%
ds_new=ds[(z<3).all(axis=1)]

# %%
ds.shape
# Out:
# (4177, 9)

# %%
ds_new.shape
# Out:
# (4027, 9)

# %%
corr_hmap=ds.corr()
plt.figure(figsize=(7,2))
sns.heatmap(corr_hmap,annot=True)
plt.show()

# %%
plt.scatter(ds['Length'],ds['Rings'])

# %%
plt.scatter(ds['Shell weight'],ds['Rings'])

# %%
#### We are not dropping any variable since none of the continous independent variables are negatively correlated with the target variable

# %%
x=ds_new.iloc[:,0:-1]

# %%
x.shape
# Out:
# (4027, 8)

# %%
y=ds_new.iloc[:,-1]

# %%
y.shape
# Out:
# (4027,)

# %%
y
# Out:
# 0       15
# 1        7
# 2        9
# 3       10
# 4        7
# 5        8
# 7       16
# 8        9
# 9       19
# 10      14
# 11      10
# 12      11
# 13      10
# 14      10
# 15      12
# 16       7
# 17      10
# 18       7
# 19       9
# 20      11
# 21      10
# 22      12
# 23       9
# 24      10
# 25      11
# 26      11
# 27      12
# 28      15
# 29      11
# 30      10
#         ..
# 4146    10
# 4147    11
# 4149     6
# 4150     7
# 4151     6
# 4152     7
# 4153     8
# 4154     6
# 4155     6
# 4156     8
# 4157     8
# 4158     8
# 4159     9
# 4160    11
# 4161    11
# 4162     8
# 4163     7
# 4164     7
# 4165     7
# 4166    10
# 4167     9
# 4168     8
# 4169    10
# 4170    10
# 4171     8
# 4172    11
# 4173    10
# 4174     9
# 4175    10
# 4176    12
# Name: Rings, Length: 4027, dtype: int64

# %%
x
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# 5       1   0.425     0.300   0.095        0.3515          0.1410
# 7       0   0.545     0.425   0.125        0.7680          0.2940
# 8       2   0.475     0.370   0.125        0.5095          0.2165
# 9       0   0.550     0.440   0.150        0.8945          0.3145
# 10      0   0.525     0.380   0.140        0.6065          0.1940
# 11      2   0.430     0.350   0.110        0.4060          0.1675
# 12      2   0.490     0.380   0.135        0.5415          0.2175
# 13      0   0.535     0.405   0.145        0.6845          0.2725
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.33,random_state=55)

# %%
x_train.shape
# Out:
# (2698, 8)

# %%
y_train.shape
# Out:
# (2698,)

# %%
x_test.shape
# Out:
# (1329, 8)

# %%
y_test.shape
# Out:
# (1329,)

# %%
lm=LinearRegression()

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
lm.intercept_
# Out:
# 2.3932848483296114

# %% [markdown]
# lm.coeff_

# %%
lm.coef_
# Out:
# array([  0.0973282 ,  -0.91939147,  11.9397653 ,  21.40661496,
#          7.08222818, -17.74058667,  -6.62570275,   7.00995718])

# %%
lm.score(x_train,y_train)
# Out:
# 0.5040435188296908

# %%
lm.predict(x_test)
# Out:
# array([11.00716518,  8.45407956,  8.91424005, ..., 11.23880348,
#        10.02113809,  9.94223839])

# %%
pred=lm.predict(x_test)

# %%
print("Predicted Age:",pred)
print("Actual Age:",y_test)
# Out:
# Predicted Age: [11.00716518  8.45407956  8.91424005 ... 11.23880348 10.02113809
#   9.94223839]
# Actual Age: 3127     9
# 3153     9
# 1126     9
# 1247     8
# 255     15
# 3454     8
# 3455     9
# 3461    11
# 2059     8
# 2449     9
# 590     13
# 1061     6
# 2637     7
# 3665     9
# 47       7
# 3320    16
# 3492     8
# 3622    10
# 161     13
# 2720     7
# 1776     9
# 2683    11
# 1713    10
# 3555     8
# 1906    11
# 2390    16
# 3361     9
# 2156    12
# 995      9
# 3294    14
#         ..
# 3043    10
# 3658    10
# 2851    12
# 658     18
# 3642     8
# 2801    10
# 3460     9
# 512     10
# 3374    10
# 1339     8
# 1058     4
# 2031    10
# 666     11
# 3237    18
# 1947    12
# 1502    11
# 1237     6
# 3913    11
# 3716     5
# 369     17
# 3687    11
# 1896     9
# 1981    12
# 925      7
# 830      6
# 151      9
# 430     18
# 1200    10
# 3273    13
# 725     17
# Name: Rings, Length: 1329, dtype: int64

# %%
print("Error:")
print(mean_squared_error(y_test,pred))
# Out:
# Error:
# 3.9370647445590565

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test,pred))
# Out:
# 0.5315001744631518
