# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import seaborn as sns
from sklearn.metrics import mean_squared_error

# %%
ds=pd.read_csv(r"C:\Users\shobhit.saxena\Music\Python_New\Projects\headbrain.csv")

# %%
ds
# Out:
#      Gender  Age Range  Head Size(cm^3)  Brain Weight(grams)
# 0         1          1             4512                 1530
# 1         1          1             3738                 1297
# 2         1          1             4261                 1335
# 3         1          1             3777                 1282
# 4         1          1             4177                 1590
# 5         1          1             3585                 1300
# 6         1          1             3785                 1400
# 7         1          1             3559                 1255
# 8         1          1             3613                 1355
# 9         1          1             3982                 1375
# 10        1          1             3443                 1340
# 11        1          1             3993                 1380
# 12        1          1             3640                 1355
# 13        1          1             4208                 1522
# ...

# %%
df=pd.DataFrame(ds)

# %%
df.head()
# Out:
#    Gender  Age Range  Head Size(cm^3)  Brain Weight(grams)
# 0       1          1             4512                 1530
# 1       1          1             3738                 1297
# 2       1          1             4261                 1335
# 3       1          1             3777                 1282
# 4       1          1             4177                 1590

# %%
df.tail()
# Out:
#      Gender  Age Range  Head Size(cm^3)  Brain Weight(grams)
# 232       2          2             3214                 1110
# 233       2          2             3394                 1215
# 234       2          2             3233                 1104
# 235       2          2             3352                 1170
# 236       2          2             3391                 1120

# %%
df.dtypes
# Out:
# Gender                 int64
# Age Range              int64
# Head Size(cm^3)        int64
# Brain Weight(grams)    int64
# dtype: object

# %%
df.describe()
# Out:
#            Gender   Age Range  Head Size(cm^3)  Brain Weight(grams)
# count  237.000000  237.000000       237.000000           237.000000
# mean     1.434599    1.535865      3633.991561          1282.873418
# std      0.496753    0.499768       365.261422           120.340446
# min      1.000000    1.000000      2720.000000           955.000000
# 25%      1.000000    1.000000      3389.000000          1207.000000
# 50%      1.000000    2.000000      3614.000000          1280.000000
# 75%      2.000000    2.000000      3876.000000          1350.000000
# max      2.000000    2.000000      4747.000000          1635.000000

# %%
df.isnull().sum()
# Out:
# Gender                 0
# Age Range              0
# Head Size(cm^3)        0
# Brain Weight(grams)    0
# dtype: int64

# %%
plt.boxplot(df['Head Size(cm^3)'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0xc2d4fd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0xc2dd978>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0xc2d4e80>],
#  'medians': [<matplotlib.lines.Line2D at 0xc2ddc88>],
#  'fliers': [<matplotlib.lines.Line2D at 0xc2e7390>],
#  'means': []}

# %%
plt.boxplot(df['Brain Weight(grams)'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0xc33d780>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0xc33de10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0xc33d390>],
#  'medians': [<matplotlib.lines.Line2D at 0xc3454e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0xc345828>],
#  'means': []}

# %%
corr_hmap=df.corr()
plt.figure(figsize=(2,2))
sns.heatmap(corr_hmap,annot=True)
plt.show()

# %%
plt.scatter(df['Brain Weight(grams)'],df['Head Size(cm^3)'])
plt.show()

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
# array([[0.8767307 , 1.07449777, 2.40886829, 2.0579083 ],
#        [0.8767307 , 1.07449777, 0.28535333, 0.11763692],
#        [0.8767307 , 1.07449777, 1.72023489, 0.43407603],
#        [0.8767307 , 1.07449777, 0.39235214, 0.00727325],
#        [0.8767307 , 1.07449777, 1.4897759 , 2.557549  ],
#        [0.8767307 , 1.07449777, 0.13441126, 0.14261896],
#        [0.8767307 , 1.07449777, 0.41430062, 0.97535345],
#        [0.8767307 , 1.07449777, 0.2057438 , 0.23211156],
#        [0.8767307 , 1.07449777, 0.05759159, 0.60062293],
#        [0.8767307 , 1.07449777, 0.95478182, 0.76716983],
#        [0.8767307 , 1.07449777, 0.52399669, 0.47571276],
#        [0.8767307 , 1.07449777, 0.98496097, 0.80880656],
#        [0.8767307 , 1.07449777, 0.01648451, 0.60062293],
#        [0.8767307 , 1.07449777, 1.57482624, 1.99128954],
#        [0.8767307 , 1.07449777, 0.54324791, 0.62349678],
#        [0.8767307 , 1.07449777, 0.66396452, 1.01699018],
# ...

# %%
treshold=3
print(np.where(z>3))
# Out:
# (array([24], dtype=int64), array([2], dtype=int64))

# %%
z[24][2]
# Out:
# 3.0536047510297246

# %%
z[24][3]
# Out:
# 2.932279519574467

# %%
df_new=ds[(z<3).all(axis=1)]

# %%
df.shape
# Out:
# (237, 4)

# %%
df_new.shape
# Out:
# (236, 4)

# %%
x=df.iloc[:,2].values
y=df.iloc[:,-1].values

# %%
x.shape
# Out:
# (237,)

# %%
x=x.reshape(-1,1)

# %%
y.shape
# Out:
# (237,)

# %%
y=y.reshape(-1,1)

# %%
x
# Out:
# array([[4512],
#        [3738],
#        [4261],
#        [3777],
#        [4177],
#        [3585],
#        [3785],
#        [3559],
#        [3613],
#        [3982],
#        [3443],
#        [3993],
#        [3640],
#        [4208],
#        [3832],
#        [3876],
#        [3497],
#        [3466],
#        [3095],
#        [4424],
#        [3878],
#        [4046],
#        [3804],
#        [3710],
#        [4747],
#        [4423],
#        [4036],
#        [4022],
#        [3454],
#        [4175],
#        [3787],
#        [3796],
#        [4103],
#        [4161],
#        [4158],
#        [3814],
#        [3527],
#        [3748],
#        [3334],
#        [3492],
#        [3962],
#        [3505],
#        [4315],
#        [3804],
#        [3863],
#        [4034],
#        [4308],
#        [3165],
#        [3641],
#        [3644],
#        [3891],
#        [3793],
#        [4270],
#        [4063],
#        [4012],
#        [3458],
#        [3890],
#        [4166],
# ...

# %%
y
# Out:
# array([[1530],
#        [1297],
#        [1335],
#        [1282],
#        [1590],
#        [1300],
#        [1400],
#        [1255],
#        [1355],
#        [1375],
#        [1340],
#        [1380],
#        [1355],
#        [1522],
#        [1208],
#        [1405],
#        [1358],
#        [1292],
#        [1340],
#        [1400],
#        [1357],
#        [1287],
#        [1275],
#        [1270],
#        [1635],
#        [1505],
#        [1490],
#        [1485],
#        [1310],
#        [1420],
#        [1318],
#        [1432],
#        [1364],
#        [1405],
#        [1432],
#        [1207],
#        [1375],
#        [1350],
#        [1236],
#        [1250],
#        [1350],
#        [1320],
#        [1525],
#        [1570],
#        [1340],
#        [1422],
#        [1506],
#        [1215],
#        [1311],
#        [1300],
#        [1224],
#        [1350],
#        [1335],
#        [1390],
#        [1400],
#        [1225],
#        [1310],
#        [1560],
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=61)

# %%
x_train.shape
# Out:
# (158, 1)

# %%
y_train.shape
# Out:
# (158, 1)

# %%
x_test.shape
# Out:
# (79, 1)

# %%
y_test.shape
# Out:
# (79, 1)

# %%
lm=LinearRegression()

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
lm.score(x,y)
# Out:
# 0.6366300217627421

# %%
lm.coef_
# Out:
# array([[0.25511761]])

# %%
lm.intercept_
# Out:
# array([361.20899878])

# %%
pred=lm.predict(x_test)

# %%
lm.predict(x_test)
# Out:
# array([[1091.8658376 ],
#        [1158.19641655],
#        [1343.66691998],
#        [1243.40569873],
#        [1306.92998395],
#        [1394.69044224],
#        [1307.69533678],
#        [1422.75337949],
#        [1291.62292727],
#        [1184.72864813],
#        [1163.55388639],
#        [1317.38980601],
#        [1345.45274326],
#        [1356.93303577],
#        [1201.05617525],
#        [1296.7252795 ],
#        [1325.29845196],
#        [1396.22114791],
#        [1182.17747201],
#        [1248.76316857],
#        [1284.22451654],
#        [1365.09679933],
#        [1312.03233617],
#        [1261.77416674],
#        [1144.67518315],
#        [1251.56946229],
#        [1275.04028253],
#        [1278.10169387],
#        [1338.81968536],
#        [1281.92845804],
#        [1170.18694428],
#        [1300.04180844],
#        [1426.32502605],
#        [1268.40722464],
#        [1229.1191125 ],
#        [1346.72833131],
#        [1379.89362079],
#        [1350.04486026],
# ...

# %%
hr=np.array([1900])       
h=hr.reshape(-1,1)

# %%
lm.predict(h)
# Out:
# array([[845.93246029]])

# %%
hr1=np.array([2300])
h2=hr1.reshape(-1,1)

# %%
lm.predict(h2)
# Out:
# array([[947.97950482]])

# %%
print("Predicted Brain Weight",pred)
print("Actual Brain Weight",y_test)
# Out:
# Predicted Brain Weight [[1091.8658376 ]
#  [1158.19641655]
#  [1343.66691998]
#  [1243.40569873]
#  [1306.92998395]
#  [1394.69044224]
#  [1307.69533678]
#  [1422.75337949]
#  [1291.62292727]
#  [1184.72864813]
#  [1163.55388639]
#  [1317.38980601]
#  [1345.45274326]
#  [1356.93303577]
#  [1201.05617525]
#  [1296.7252795 ]
#  [1325.29845196]
#  [1396.22114791]
#  [1182.17747201]
#  [1248.76316857]
#  [1284.22451654]
#  [1365.09679933]
#  [1312.03233617]
#  [1261.77416674]
#  [1144.67518315]
#  [1251.56946229]
#  [1275.04028253]
#  [1278.10169387]
#  [1338.81968536]
#  [1281.92845804]
#  [1170.18694428]
#  [1300.04180844]
#  [1426.32502605]
#  [1268.40722464]
#  [1229.1191125 ]
#  [1346.72833131]
#  [1379.89362079]
#  [1350.04486026]
#  [1227.0781716 ]
#  [1383.72038496]
#  [1189.32076513]
#  [1343.41180237]
#  [1144.16494793]
#  [1357.95350621]
#  [1231.92540622]
#  [1238.55846411]
#  [1242.38522828]
#  [1226.31281877]
#  [1226.31281877]
#  [1336.77874447]
#  [1110.48942323]
# ...

# %%
print("Error")            ############## Mean Squared Error
print(mean_squared_error(y_test,pred))
# Out:
# Error
# 6036.749098419116

# %%
from sklearn.metrics import r2_score ######## R-Squared score
print(r2_score(y_test,pred))
# Out:
# 0.6042419497393148
